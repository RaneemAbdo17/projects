# %% [markdown]
# <a href="https://www.kaggle.com/code/raneemabdo/lin-alg?scriptVersionId=143623489" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
v1=np.array([5,4,3])
v2=np.array([1,8,4])
v1+v2
v1-v2
v1@v2
v1*4

# %%
from math import inf

# %%
np.linalg.norm(v2,inf)

# %%
y=np.arange(0,20)
y_hat=np.arange(0,20)*0.3
e=y_hat-y
np.linalg.norm(e)**2/e.shape[0]

# %%
np.linalg.norm(e,1)/e.shape[0]

# %%
arr=np.array([[2,3,4]])
arr2=np.array([[1],[9],[5]])
arr3=np.array([[1],[9],[5]])

arr3.T@arr2

# %%
pip install sympy

# %%
import sympy as sm

# %%
arr=np.array([[2,3,4],[6,7,8]])
m=sm.Matrix(arr)
m.rref()

# %%
np.linalg.matrix_rank(arr)

# %%
t=np.array([[1,1],[0,2]])
val,vec=np.linalg.eig(t)
d=np.diag(val)
vv=np.linalg.inv(t)
vv
