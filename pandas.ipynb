# %% [markdown]
# <a href="https://www.kaggle.com/code/raneemabdo/pandas?scriptVersionId=143619901" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
from pandas.core.arrays.sparse import SparseArray as _SparseArray

# %%
df=pd.read_csv('/kaggle/input/microsoft-stock-time-series-analysis/Microsoft_Stock.csv')

# %%
df.head()

# %%
df['Date']
df.Date

# %%
df.loc[1:3]

# %%
df.iloc[[1,2,3],[3,4]]

# %%
df.set_index('Date')

# %%
df.loc[df.High>40]

# %%
df.loc[(df.High>200)&(df.Close>50)]

# %%
df.Close.isin([200.57,201.91])

# %%
df['Date'].isnull()

# %%
df.isnull().sum()

# %%
df = pd.DataFrame({'names':['raneem','ahmed','doaa'],'ages':[22,33,44],'toy':[np.nan,'rr','tt']})
df

# %%
df.isnull().sum()

# %%
df2=df.dropna()
df2

# %%
df3=df.dropna(axis='columns')
df3

# %%
 df4=df.dropna(subset=['toy'])
 df4

# %%
df7=df.fillna(0)
df7

# %%
df.fillna(method='bfill') #or ffill

# %%
df6=df['names'].replace('raneem',np.nan)
df6

# %%
df['ages'].value_counts()
df['ages'].astype(float)
